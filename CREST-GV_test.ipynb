# %%
import warnings
warnings.filterwarnings('ignore')

from IPython.core.display import display, HTML
display(HTML('<style>.container {width: 90% !important; }</style>'))

import glob, pyBigWig, shutil, os
import pandas as pd

import sys
sys.path.append('crestgv/')
from crestgv import crestgv
# Out:
# <style>.container {width: 90% !important; }</style>

# %% [markdown]
# ### Genetic less than 100

# %%
genetic  = "genetics_test/less100.tsv"
cgv      = crestgv(genetic=genetic, output="CREST-GV_test/less100", min_number_genetics=100, collection_name="super_pbmc")
df_cgv   = cgv.calculate_enrichment_score(lessNG=False, greater25k=False)
df_cover = cgv.get_coverage()
# Out:
# Removing NaN rows from loaded file ...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Genetics provided after quality control contains less than the minimum number 'min_number_genetics' of entries.
# If you want to carry on anyway with it, please set 'lessNG=True'.

# %%
df_cgv   = cgv.calculate_enrichment_score(lessNG=True, greater25k=False)
df_cover = cgv.get_coverage()
# Out:
# Removing NaN rows from loaded file ...
# Total number of used variants in CREST-GV: 62
# Calculating (1) total number of base-pairs within peaks and (2) total number of base-pairs within peaks divided by uniquely mappable base-pairs ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 23.39it/s]
# Intersecting genetic with peak regions ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:03<00:00,  5.30it/s]
# ...
# For each fold, parallelised shuffling background ...
# Adding shuffled background ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:18<00:00,  3.76s/it]
# Calculating statistics ...
# Cleaning temporary files ...
# Processing genetics finished.
# Removing NaN rows from loaded file ...
# ...

# %% [markdown]
# ### Genetic greater than 25k

# %%
genetic  = "genetics_test/greater25k.tsv"
cgv      = crestgv(genetic=genetic, output="CREST-GV_test/grater25k", min_number_genetics=1000, collection_name="super_pbmc")
df_cgv   = cgv.calculate_enrichment_score(lessNG=False, greater25k=False)
df_cover = cgv.get_coverage()
# Out:
# Removing NaN rows from loaded file ...
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Genetics provided after quality control contains more than 25k entry variants.
# If you want to carry on anyway with it, please set 'greater25k=True'.
# If this is the case, it might take hours if not days to compute the CREST-GV scores!

# %%
genetic  = "genetics_test/greater25k.tsv"
cgv      = crestgv(genetic=genetic, output="CREST-GV_test/grater25k", min_number_genetics=1000, collection_name="super_pbmc")
df_cgv   = cgv.calculate_enrichment_score(lessNG=False, greater25k=True)
df_cover = cgv.get_coverage()
# Out:
# Removing NaN rows from loaded file ...
# Total number of used variants in CREST-GV: 26518
# Calculating (1) total number of base-pairs within peaks and (2) total number of base-pairs within peaks divided by uniquely mappable base-pairs ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 25.22it/s]
# Intersecting genetic with peak regions ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:04<00:00,  4.68it/s]
# For each fold, parallelised shuffling background ...
# Calculating (1) total number of base-pairs within peaks and (2) total number of base-pairs within peaks divided by uniquely mappable base-pairs ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 22.54it/s]
# ...

# %% [markdown]
# ### Bcell_GO_0035456 genetic

# %%
genetic  = "genetics_test/Bcell_GO_0035456.tsv"
cgv      = crestgv(genetic=genetic, output="CREST-GV_test/Bcell_GO_0035456", min_number_genetics=100, collection_name="super_pbmc")
df_cgv   = cgv.calculate_enrichment_score(lessNG=False, greater25k=False)
df_cover = cgv.get_coverage()
# Out:
# Removing NaN rows from loaded file ...
# Total number of used variants in CREST-GV: 527
# Calculating (1) total number of base-pairs within peaks and (2) total number of base-pairs within peaks divided by uniquely mappable base-pairs ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 23.02it/s]
# Intersecting genetic with peak regions ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:04<00:00,  4.72it/s]
# ...
# For each fold, parallelised shuffling background ...
# Calculating (1) total number of base-pairs within peaks and (2) total number of base-pairs within peaks divided by uniquely mappable base-pairs ...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 23.62it/s]
# Intersecting genetic with peak regions ...
# ...
