# %%
import warnings
warnings.filterwarnings('ignore')

from IPython.core.display import display, HTML
display(HTML('<style>.container {width: 90% !important; }</style>'))

# %%
import sys
import pandas as pd
import time
sys.path.append('ensgen/')

# %%
from ensgen import ensgen

# %% [markdown]
# # cell type prioritisation fibro_lauryn_MS

# %%
# genetic_file = "/project/hugheslab/datashare/avocato/genetics_lead/hg38/03_MS_genetics_from_GWAScatalog.txt"

# %%
# eg = ensgen(genetic=genetic_file, seed=42, output="fibro_lauryn_MS")
# df = eg.process_genetics_for_customdata()

# %%
# genetic_file = "/project/hugheslab/datashare/avocato/genetics_lead/hg38/01_type1diabetes_genetics_from_GWAScatalog.txt"

# %%
# eg = ensgen(genetic=genetic_file, seed=42, output="fibro_lauryn_type1diabetes")
# df = eg.process_genetics_for_customdata()

# %% [markdown]
# # cell type prioritisation

# %%
# genetic_file = "multiome_ery_matt_Astle/astle_genetics_subset.tsv"

# eg = ensgen(genetic=genetic_file, seed=42, output="multiome_ery_matt_Astle")
# df = eg.process_genetics_for_multiome_ery()

# %%
# genetic_file = "multiome_ery_matt_Vuckovic/vuckovic_genetics_subset.tsv"

# eg = ensgen(genetic=genetic_file, seed=42, output="multiome_ery_matt_Vuckovic")
# df = eg.process_genetics_for_multiome_ery()

# %%
# genetic_file = "multiome_ery_matt_vanderHarst/vanderHarst_genetics_subset.tsv"

# eg = ensgen(genetic=genetic_file, seed=42, output="multiome_ery_matt_vanderHarst")
# df = eg.process_genetics_for_multiome_ery()
